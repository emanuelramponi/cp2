# %%
import pandas as pd
import numpy as np

# %%
##### DATA ################

# 5+ Years of stock prices: Apple, Facebook, Microsoft, Google, and Amazon

# https://andybek.com/pandas-tech

# %%
tech_url = 'https://andybek.com/pandas-tech'
tech = pd.read_csv(tech_url)
tech.head()
# Out:
#          date  month  year  day   name    open   close    high     low  \
# 0  2014-01-02      1  2014    2     FB   54.86   54.71   55.22   54.19
# 1  2014-01-02      1  2014    2   AAPL   79.38   79.02   79.58   78.86
# 2  2014-01-02      1  2014    2  GOOGL  557.73  556.56  558.88  554.13
# 3  2014-01-02      1  2014    2   MSFT   37.35   37.16   37.40   37.10
# 4  2014-01-02      1  2014    2   AMZN  398.80  397.97  399.36  394.02
#
#      volume volume_type
# 0  43257622      medium
# 1   8398851         low
# 2   1822719      medium
# 3  30643745      medium
# 4   2140246      medium

# %% [markdown]
# #### 171. Index And RangeIndex

# %%
## index es para filas no se puede cambiar, es inmodificable. RangeIndex
type(tech.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
# columnas corresponde a Index.
type(tech.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# #### 172. Creating A MultiIndex

# %%
# A single sindex object has more than one level or component to it.
tech.set_index(['date','name'], inplace=True)

# %%
tech.head(10)
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB         1  2014    2   54.86   54.71   55.22   54.19  43257622
#            AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851
#            GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719
#            MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745
#            AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246
# 2014-01-03 FB         1  2014    3   55.00   54.56   55.65   54.53  38287706
#            GOOGL      1  2014    3  557.50  552.50  558.47  552.47   1669229
#            MSFT       1  2014    3   37.20   36.91   37.22   36.60  31134795
#            AAPL       1  2014    3   79.00   77.28   79.10   77.20  14043410
#            AMZN       1  2014    3  398.29  396.44  402.71  396.22   2213512
#
#                  volume_type
# date       name
# 2014-01-02 FB         medium
# ...

# %%
type(tech.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %% [markdown]
# #### 173. MultiIndex From read_csv()

# %%
pd.read_csv(tech_url,index_col=['date','name'])
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-02 FB         1  2014    2    54.86    54.71    55.22    54.19
#            AAPL       1  2014    2    79.38    79.02    79.58    78.86
#            GOOGL      1  2014    2   557.73   556.56   558.88   554.13
#            MSFT       1  2014    2    37.35    37.16    37.40    37.10
#            AMZN       1  2014    2   398.80   397.97   399.36   394.02
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-08-23 MSFT       8  2019   23   137.19   133.39   138.35   132.80
#            AAPL       8  2019   23   209.43   202.64   212.05   201.00
#            GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
#            AMZN       8  2019   23  1793.03  1749.62  1804.90  1745.23
#            FB         8  2019   23   180.84   177.75   183.13   176.66
#
#                     volume volume_type
# date       name
# 2014-01-02 FB     43257622      medium
# ...

# %% [markdown]
# #### 174. Indexing Hierarchical DataFrames

# %%
tech.loc['2014-01-02']
# Out:
#        month  year  day    open   close    high     low    volume volume_type
# name
# FB         1  2014    2   54.86   54.71   55.22   54.19  43257622      medium
# AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851         low
# GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719      medium
# MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745      medium
# AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246      medium

# %%
tech.loc['2014-01-02','GOOGL']
# Out:
# month                1
# year              2014
# day                  2
# open            557.73
# close           556.56
# high            558.88
# low             554.13
# volume         1822719
# volume_type     medium
# Name: (2014-01-02, GOOGL), dtype: object

# %%
tech.loc['2014-01-02','GOOGL'].close
# Out:
# 556.56

# %%
tech.loc[('2014-01-02','GOOGL'), 'close']
# Out:
# 556.56

# %%
# agnostic -> having a non comittal attitude or belief

# %%
# iloc -> agnostic to hierarchichal dfs
# loc  -> cares

# %%
tech.head()
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB         1  2014    2   54.86   54.71   55.22   54.19  43257622
#            AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851
#            GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719
#            MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745
#            AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246
#
#                  volume_type
# date       name
# 2014-01-02 FB         medium
#            AAPL          low
#            GOOGL      medium
#            MSFT       medium
#            AMZN       medium

# %%
tech.iloc[2,4]
# Out:
# 556.56

# %% [markdown]
# ##### the label-based approach

# %%
tech.loc[('2014-01-03','AAPL'),'open':'close']
# Out:
# open     79.00
# close    77.28
# Name: (2014-01-03, AAPL), dtype: float64

# %% [markdown]
# ###### the position-based approach

# %%
tech.iloc[8,3:5]
# Out:
# open     79.00
# close    77.28
# Name: (2014-01-03, AAPL), dtype: float64

# %% [markdown]
# ###### select multiple days

# %%
tech.loc[['2015-01-06','2015-01-07']]
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2015-01-06 AAPL       1  2015    6  106.54  106.26  107.43  104.63  65797116
#            FB         1  2015    6   77.23   76.15   77.59   75.36  27399288
#            AMZN       1  2015    6  302.20  295.29  303.00  292.38   3519034
#            MSFT       1  2015    6   46.38   45.65   46.75   45.54  36447854
#            GOOGL      1  2015    6  520.49  506.64  521.21  505.55   2731813
# 2015-01-07 FB         1  2015    7   76.76   76.15   77.36   75.82  22045333
#            MSFT       1  2015    7   45.98   46.23   46.46   45.49  29114061
#            GOOGL      1  2015    7  510.99  505.15  511.49  503.65   2345875
#            AMZN       1  2015    7  297.54  298.42  301.28  295.33   2640349
#            AAPL       1  2015    7  107.20  107.75  108.20  106.70  40105934
#
#                  volume_type
# date       name
# 2015-01-06 AAPL       medium
# ...

# %%
# tech.loc[['2015-01-06','2015-01-07'],['FB','AMZN']] # this won´t work

# %%
tech.loc[(['2015-01-06','2015-01-07'],['FB','AMZN']),:]
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2015-01-06 FB        1  2015    6   77.23   76.15   77.59   75.36  27399288
#            AMZN      1  2015    6  302.20  295.29  303.00  292.38   3519034
# 2015-01-07 FB        1  2015    7   76.76   76.15   77.36   75.82  22045333
#            AMZN      1  2015    7  297.54  298.42  301.28  295.33   2640349
#
#                 volume_type
# date       name
# 2015-01-06 FB        medium
#            AMZN      medium
# 2015-01-07 FB        medium
#            AMZN      medium

# %%
tech.loc[(['2015-01-06','2015-01-07'],['FB','AMZN']), 'open':'close']
# Out:
#                    open   close
# date       name
# 2015-01-06 FB     77.23   76.15
#            AMZN  302.20  295.29
# 2015-01-07 FB     76.76   76.15
#            AMZN  297.54  298.42

# %% [markdown]
# ###### the silce() object

# %%
tech.loc[(slice('2017-01-03','2017-01-31'),['FB','AMZN']),'open':'low'].head(10)
# Out:
#                    open   close    high     low
# date       name
# 2017-01-03 AMZN  757.92  753.67  758.76  747.70
#            FB    116.03  116.86  117.84  115.51
# 2017-01-04 AMZN  758.39  757.18  759.68  754.20
#            FB    117.55  118.69  119.66  117.29
# 2017-01-05 AMZN  761.55  780.45  782.40  760.26
#            FB    118.86  120.67  120.95  118.32
# 2017-01-06 FB    120.98  123.41  123.88  120.03
#            AMZN  782.36  795.99  799.44  778.48
# 2017-01-09 AMZN  798.00  796.92  801.77  791.77
#            FB    123.55  124.90  125.43  123.04

# %% [markdown]
# #### 176. BONUS - Use : With pd.IndexSlice!

# %%
tech.loc[pd.IndexSlice[:,['FB','AMZN']],'high':'low']
# Out:
#                     high      low
# date       name
# 2014-01-02 FB      55.22    54.19
# 2014-01-03 FB      55.65    54.53
# 2014-01-06 FB      57.26    54.05
# 2014-01-07 FB      58.55    57.22
# 2014-01-08 FB      58.41    57.23
# ...                  ...      ...
# 2019-08-19 AMZN  1826.00  1812.61
# 2019-08-20 AMZN  1816.82  1799.88
# 2019-08-21 AMZN  1829.58  1815.00
# 2019-08-22 AMZN  1829.41  1800.10
# 2019-08-23 AMZN  1804.90  1745.23
#
# [2842 rows x 2 columns]

# %%
i = pd.IndexSlice

# %%
tech.loc[i[:,'FB'],'high':'low']
# Out:
#                    high     low
# date       name
# 2014-01-02 FB     55.22   54.19
# 2014-01-03 FB     55.65   54.53
# 2014-01-06 FB     57.26   54.05
# 2014-01-07 FB     58.55   57.22
# 2014-01-08 FB     58.41   57.23
# ...                 ...     ...
# 2019-08-19 FB    187.50  184.85
# 2019-08-20 FB    186.00  182.39
# 2019-08-21 FB    185.90  183.14
# 2019-08-22 FB    184.11  179.91
# 2019-08-23 FB    183.13  176.66
#
# [1421 rows x 2 columns]

# %%
# jan 6 - jan 10

# %%
tech.loc[i['2014-01-06':'2014-01-10',['FB','AMZN']],'high':'low'].head()
# Out:
#                    high     low
# date       name
# 2014-01-06 AMZN  397.00  388.42
#            FB     57.26   54.05
# 2014-01-07 FB     58.55   57.22
#            AMZN  398.47  394.29
# 2014-01-08 AMZN  403.00  396.04

# %% [markdown]
# #### 177. Cross Sections With xs()

# %% [markdown]
# ###### xs() is a type of label-based indexing

# %%
tech.xs('2019-01-02')
# Out:
#        month  year  day     open    close     high      low    volume  \
# name
# MSFT       1  2019    2    99.55   101.12   101.75    98.94  35329345
# FB         1  2019    2   128.99   135.68   137.51   128.56  28146193
# GOOGL      1  2019    2  1027.20  1054.68  1060.79  1025.28   1593395
# AMZN       1  2019    2  1465.20  1539.13  1553.36  1460.93   7983103
# AAPL       1  2019    2   154.89   157.92   158.85   154.23  37039737
#
#       volume_type
# name
# MSFT       medium
# FB         medium
# GOOGL      medium
# AMZN       medium
# AAPL       medium

# %%
tech.loc['2019-01-02']
# Out:
#        month  year  day     open    close     high      low    volume  \
# name
# MSFT       1  2019    2    99.55   101.12   101.75    98.94  35329345
# FB         1  2019    2   128.99   135.68   137.51   128.56  28146193
# GOOGL      1  2019    2  1027.20  1054.68  1060.79  1025.28   1593395
# AMZN       1  2019    2  1465.20  1539.13  1553.36  1460.93   7983103
# AAPL       1  2019    2   154.89   157.92   158.85   154.23  37039737
#
#       volume_type
# name
# MSFT       medium
# FB         medium
# GOOGL      medium
# AMZN       medium
# AAPL       medium

# %%
tech.loc[(slice(None),'FB'),:].head()
# Out:
#                  month  year  day   open  close   high    low    volume  \
# date       name
# 2014-01-02 FB        1  2014    2  54.86  54.71  55.22  54.19  43257622
# 2014-01-03 FB        1  2014    3  55.00  54.56  55.65  54.53  38287706
# 2014-01-06 FB        1  2014    6  54.39  57.20  57.26  54.05  68974359
# 2014-01-07 FB        1  2014    7  57.67  57.92  58.55  57.22  77329009
# 2014-01-08 FB        1  2014    8  57.59  58.23  58.41  57.23  56800776
#
#                 volume_type
# date       name
# 2014-01-02 FB        medium
# 2014-01-03 FB        medium
# 2014-01-06 FB          high
# 2014-01-07 FB          high
# 2014-01-08 FB          high

# %%
tech.xs('FB',level=1).head()
# Out:
#             month  year  day   open  close   high    low    volume volume_type
# date
# 2014-01-02      1  2014    2  54.86  54.71  55.22  54.19  43257622      medium
# 2014-01-03      1  2014    3  55.00  54.56  55.65  54.53  38287706      medium
# 2014-01-06      1  2014    6  54.39  57.20  57.26  54.05  68974359        high
# 2014-01-07      1  2014    7  57.67  57.92  58.55  57.22  77329009        high
# 2014-01-08      1  2014    8  57.59  58.23  58.41  57.23  56800776        high

# %%
tech.xs('FB',level=1,drop_level=False).head()
# Out:
#                  month  year  day   open  close   high    low    volume  \
# date       name
# 2014-01-02 FB        1  2014    2  54.86  54.71  55.22  54.19  43257622
# 2014-01-03 FB        1  2014    3  55.00  54.56  55.65  54.53  38287706
# 2014-01-06 FB        1  2014    6  54.39  57.20  57.26  54.05  68974359
# 2014-01-07 FB        1  2014    7  57.67  57.92  58.55  57.22  77329009
# 2014-01-08 FB        1  2014    8  57.59  58.23  58.41  57.23  56800776
#
#                 volume_type
# date       name
# 2014-01-02 FB        medium
# 2014-01-03 FB        medium
# 2014-01-06 FB          high
# 2014-01-07 FB          high
# 2014-01-08 FB          high

# %%
# selecting from multiple level at once
tech.xs(('2019-01-02','FB'),level=(0,1))
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2019-01-02 FB        1  2019    2  128.99  135.68  137.51  128.56  28146193
#
#                 volume_type
# date       name
# 2019-01-02 FB        medium

# %% [markdown]
# #### 178. Skill Challenge

# %% [markdown]
# ##### 1. From the thech dataframe, select all the stock prices between July 13, 2015 and August 17, 2016. Assing the resulting dataframe slice to the variable tech_df2

# %%
# tech.loc[(slice('2015-07-13','2016-08-17'),'FB'),]
tech_df2=tech.loc[(slice('2015-07-13','2016-08-17'))] 
tech_df2.head(10)
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2015-07-13 MSFT       7  2015   13   44.98   45.54   45.62   44.95  28178329
#            AMZN       7  2015   13  448.29  455.57  457.87  447.54   3956802
#            FB         7  2015   13   88.66   90.10   90.22   88.42  29976670
#            GOOGL      7  2015   13  559.51  571.73  572.85  558.70   2089641
#            AAPL       7  2015   13  125.03  125.66  125.76  124.32  41440538
# 2015-07-14 AMZN       7  2015   14  462.32  465.57  469.60  458.16   4736215
#            GOOGL      7  2015   14  574.50  584.18  589.71  574.17   3741583
#            MSFT       7  2015   14   45.45   45.62   45.96   45.31  22880260
#            FB         7  2015   14   90.46   89.68   90.80   89.65  26627849
#            AAPL       7  2015   14  126.04  125.61  126.37  125.04  31768139
#
#                  volume_type
# date       name
# 2015-07-13 MSFT       medium
# ...

# %%
tech.loc[pd.IndexSlice['2015-07-13':'2016-08-17'],].head(10)
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2015-07-13 MSFT       7  2015   13   44.98   45.54   45.62   44.95  28178329
#            AMZN       7  2015   13  448.29  455.57  457.87  447.54   3956802
#            FB         7  2015   13   88.66   90.10   90.22   88.42  29976670
#            GOOGL      7  2015   13  559.51  571.73  572.85  558.70   2089641
#            AAPL       7  2015   13  125.03  125.66  125.76  124.32  41440538
# 2015-07-14 AMZN       7  2015   14  462.32  465.57  469.60  458.16   4736215
#            GOOGL      7  2015   14  574.50  584.18  589.71  574.17   3741583
#            MSFT       7  2015   14   45.45   45.62   45.96   45.31  22880260
#            FB         7  2015   14   90.46   89.68   90.80   89.65  26627849
#            AAPL       7  2015   14  126.04  125.61  126.37  125.04  31768139
#
#                  volume_type
# date       name
# 2015-07-13 MSFT       medium
# ...

# %% [markdown]
# ##### 2. Select 10 days at random from tech_df2 containing only AAPL price data

# %%
tech_df2.xs('AAPL',level=1,drop_level=False).sample(10)
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2015-11-30 AAPL     11  2015   30  117.99  118.30  119.41  117.75  39180322
# 2016-01-26 AAPL      1  2016   26   99.93   99.99  100.88   98.07  75077002
# 2016-05-06 AAPL      5  2016    6   93.37   92.72   93.45   91.85  43699886
# 2016-08-15 AAPL      8  2016   15  108.14  109.48  109.54  108.08  25868209
# 2015-10-28 AAPL     10  2015   28  116.93  119.27  119.30  116.06  85551352
# 2016-04-06 AAPL      4  2016    6  110.23  110.96  110.98  109.20  26404077
# 2015-11-23 AAPL     11  2015   23  119.27  117.75  119.73  117.34  32482528
# 2016-02-12 AAPL      2  2016   12   94.19   93.99   94.50   93.01  40351381
# 2016-02-17 AAPL      2  2016   17   96.67   98.12   98.21   96.15  44863243
# 2015-09-08 AAPL      9  2015    8  111.65  112.31  112.56  110.32  54843626
#
#                 volume_type
# date       name
# 2015-11-30 AAPL      medium
# 2016-01-26 AAPL        high
# ...

# %%
tech_df2.loc[(slice(None),'AAPL'),:].sample(10)
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2016-08-09 AAPL      8  2016    9  108.23  108.81  108.94  108.01  26315204
# 2016-07-20 AAPL      7  2016   20  100.00   99.96  100.46   99.74  26275968
# 2015-10-13 AAPL     10  2015   13  110.82  111.79  112.45  110.68  33049256
# 2015-08-10 AAPL      8  2015   10  116.53  119.72  119.99  116.53  54951597
# 2016-07-22 AAPL      7  2016   22   99.26   98.66   99.30   98.31  28313669
# 2016-06-03 AAPL      6  2016    3   97.79   97.92   98.27   97.45  28504888
# 2015-11-18 AAPL     11  2015   18  115.76  117.29  117.49  115.50  46674697
# 2015-12-11 AAPL     12  2015   11  115.19  113.18  115.39  112.85  46886161
# 2015-09-04 AAPL      9  2015    4  108.97  109.27  110.45  108.51  49996311
# 2016-05-13 AAPL      5  2016   13   90.00   90.52   91.67   90.00  44392765
#
#                 volume_type
# date       name
# 2016-08-09 AAPL      medium
# 2016-07-20 AAPL      medium
# ...

# %% [markdown]
# ##### 3. Select all the intraday high and low prices for AAPL and GOOGL for all the dates in tech_df2

# %%
tech_df2.loc[(slice(None),['AAPL','GOOGL']),'high':'low']
# Out:
#                     high     low
# date       name
# 2015-07-13 AAPL   125.76  124.32
# 2015-07-14 AAPL   126.37  125.04
# 2015-07-15 AAPL   127.15  125.58
# 2015-07-16 AAPL   128.57  127.35
# 2015-07-17 AAPL   129.62  128.31
# ...                  ...     ...
# 2016-08-11 GOOGL  813.88  806.00
# 2016-08-12 GOOGL  807.19  803.64
# 2016-08-15 GOOGL  811.36  804.03
# 2016-08-16 GOOGL  804.26  797.00
# 2016-08-17 GOOGL  805.63  796.30
#
# [558 rows x 2 columns]

# %%
tech_df2.loc[pd.IndexSlice[:,['AAPL','GOOGL']],'high':'low']
# Out:
#                     high     low
# date       name
# 2015-07-13 AAPL   125.76  124.32
# 2015-07-14 AAPL   126.37  125.04
# 2015-07-15 AAPL   127.15  125.58
# 2015-07-16 AAPL   128.57  127.35
# 2015-07-17 AAPL   129.62  128.31
# ...                  ...     ...
# 2016-08-11 GOOGL  813.88  806.00
# 2016-08-12 GOOGL  807.19  803.64
# 2016-08-15 GOOGL  811.36  804.03
# 2016-08-16 GOOGL  804.26  797.00
# 2016-08-17 GOOGL  805.63  796.30
#
# [558 rows x 2 columns]

# %% [markdown]
# #### 180. The Anatomy Of A MultiIndex Object

# %%
type(tech.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
tech.index
# Out:
# MultiIndex([('2014-01-02',    'FB'),
#             ('2014-01-02',  'AAPL'),
#             ('2014-01-02', 'GOOGL'),
#             ('2014-01-02',  'MSFT'),
#             ('2014-01-02',  'AMZN'),
#             ('2014-01-03',    'FB'),
#             ('2014-01-03', 'GOOGL'),
#             ('2014-01-03',  'MSFT'),
#             ('2014-01-03',  'AAPL'),
#             ('2014-01-03',  'AMZN'),
#             ...
#             ('2019-08-22',  'MSFT'),
#             ('2019-08-22',    'FB'),
#             ('2019-08-22',  'AMZN'),
#             ('2019-08-22',  'AAPL'),
#             ('2019-08-22', 'GOOGL'),
#             ('2019-08-23',  'MSFT'),
#             ('2019-08-23',  'AAPL'),
#             ('2019-08-23', 'GOOGL'),
#             ('2019-08-23',  'AMZN'),
#             ('2019-08-23',    'FB')],
#            names=['date', 'name'], length=7105)

# %% [markdown]
# ##### names

# %%
tech.index.names
# Out:
# FrozenList(['date', 'name'])

# %% [markdown]
# ##### levels

# %%
tech.index.nlevels
# Out:
# 2

# %%
len(tech.index.levels) == tech.index.nlevels
# Out:
# True

# %%
tech.index.levels[0]
tech
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-02 FB         1  2014    2    54.86    54.71    55.22    54.19
#            AAPL       1  2014    2    79.38    79.02    79.58    78.86
#            GOOGL      1  2014    2   557.73   556.56   558.88   554.13
#            MSFT       1  2014    2    37.35    37.16    37.40    37.10
#            AMZN       1  2014    2   398.80   397.97   399.36   394.02
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-08-23 MSFT       8  2019   23   137.19   133.39   138.35   132.80
#            AAPL       8  2019   23   209.43   202.64   212.05   201.00
#            GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
#            AMZN       8  2019   23  1793.03  1749.62  1804.90  1745.23
#            FB         8  2019   23   180.84   177.75   183.13   176.66
#
#                     volume volume_type
# date       name
# 2014-01-02 FB     43257622      medium
# ...

# %%
tech.index.levels[1]
# Out:
# Index(['AAPL', 'AMZN', 'FB', 'GOOGL', 'MSFT'], dtype='object', name='name')

# %% [markdown]
# ##### levshape

# %%
tech.index.levshape
# Out:
# (1421, 5)

# %% [markdown]
# ###### values

# %%
tech.index.values
# Out:
# array([('2014-01-02', 'FB'), ('2014-01-02', 'AAPL'),
#        ('2014-01-02', 'GOOGL'), ..., ('2019-08-23', 'GOOGL'),
#        ('2019-08-23', 'AMZN'), ('2019-08-23', 'FB')], dtype=object)

# %% [markdown]
# #### 182. Shuffing Levels

# %%
# adding another level
tech.set_index('volume_type',append=True,inplace=True)

# %% [markdown]
# ##### swaplevel()

# %%
tech = tech.swaplevel(2,1)
tech
# Out:
#                               month  year  day     open    close     high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2    54.86    54.71    55.22
#            low         AAPL       1  2014    2    79.38    79.02    79.58
#            medium      GOOGL      1  2014    2   557.73   556.56   558.88
#                        MSFT       1  2014    2    37.35    37.16    37.40
#                        AMZN       1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-23 medium      MSFT       8  2019   23   137.19   133.39   138.35
#                        AAPL       8  2019   23   209.43   202.64   212.05
#                        GOOGL      8  2019   23  1185.17  1153.58  1195.67
#                        AMZN       8  2019   23  1793.03  1749.62  1804.90
#                        FB         8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech.swaplevel('volume_type','name')
# Out:
#                               month  year  day     open    close     high  \
# date       name  volume_type
# 2014-01-02 FB    medium           1  2014    2    54.86    54.71    55.22
#            AAPL  low              1  2014    2    79.38    79.02    79.58
#            GOOGL medium           1  2014    2   557.73   556.56   558.88
#            MSFT  medium           1  2014    2    37.35    37.16    37.40
#            AMZN  medium           1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-23 MSFT  medium           8  2019   23   137.19   133.39   138.35
#            AAPL  medium           8  2019   23   209.43   202.64   212.05
#            GOOGL medium           8  2019   23  1185.17  1153.58  1195.67
#            AMZN  medium           8  2019   23  1793.03  1749.62  1804.90
#            FB    medium           8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %% [markdown]
# ##### reorder_levels()

# %%
tech.reorder_levels([2,0,1]).head()
# Out:
#                               month  year  day    open   close    high  \
# name  date       volume_type
# FB    2014-01-02 medium           1  2014    2   54.86   54.71   55.22
# AAPL  2014-01-02 low              1  2014    2   79.38   79.02   79.58
# GOOGL 2014-01-02 medium           1  2014    2  557.73  556.56  558.88
# MSFT  2014-01-02 medium           1  2014    2   37.35   37.16   37.40
# AMZN  2014-01-02 medium           1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# name  date       volume_type
# FB    2014-01-02 medium        54.19  43257622
# AAPL  2014-01-02 low           78.86   8398851
# GOOGL 2014-01-02 medium       554.13   1822719
# MSFT  2014-01-02 medium        37.10  30643745
# AMZN  2014-01-02 medium       394.02   2140246

# %% [markdown]
# #### 183. Removing MultiIndex Levels

# %% [markdown]
# ##### droplevel()

# %%
tech.droplevel(1)
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-02 FB         1  2014    2    54.86    54.71    55.22    54.19
#            AAPL       1  2014    2    79.38    79.02    79.58    78.86
#            GOOGL      1  2014    2   557.73   556.56   558.88   554.13
#            MSFT       1  2014    2    37.35    37.16    37.40    37.10
#            AMZN       1  2014    2   398.80   397.97   399.36   394.02
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-08-23 MSFT       8  2019   23   137.19   133.39   138.35   132.80
#            AAPL       8  2019   23   209.43   202.64   212.05   201.00
#            GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
#            AMZN       8  2019   23  1793.03  1749.62  1804.90  1745.23
#            FB         8  2019   23   180.84   177.75   183.13   176.66
#
#                     volume
# date       name
# 2014-01-02 FB     43257622
# ...

# %% [markdown]
# ##### reset_index()

# %%
tech.reset_index(level=1,drop=False)
# Out:
#                  volume_type  month  year  day     open    close     high  \
# date       name
# 2014-01-02 FB         medium      1  2014    2    54.86    54.71    55.22
#            AAPL          low      1  2014    2    79.38    79.02    79.58
#            GOOGL      medium      1  2014    2   557.73   556.56   558.88
#            MSFT       medium      1  2014    2    37.35    37.16    37.40
#            AMZN       medium      1  2014    2   398.80   397.97   399.36
# ...                      ...    ...   ...  ...      ...      ...      ...
# 2019-08-23 MSFT       medium      8  2019   23   137.19   133.39   138.35
#            AAPL       medium      8  2019   23   209.43   202.64   212.05
#            GOOGL      medium      8  2019   23  1185.17  1153.58  1195.67
#            AMZN       medium      8  2019   23  1793.03  1749.62  1804.90
#            FB         medium      8  2019   23   180.84   177.75   183.13
#
#                       low    volume
# date       name
# ...

# %%
# removing multiple or several levels at once
tech.reset_index(level=[1,2],drop=False)
# Out:
#            volume_type   name  month  year  day     open    close     high  \
# date
# 2014-01-02      medium     FB      1  2014    2    54.86    54.71    55.22
# 2014-01-02         low   AAPL      1  2014    2    79.38    79.02    79.58
# 2014-01-02      medium  GOOGL      1  2014    2   557.73   556.56   558.88
# 2014-01-02      medium   MSFT      1  2014    2    37.35    37.16    37.40
# 2014-01-02      medium   AMZN      1  2014    2   398.80   397.97   399.36
# ...                ...    ...    ...   ...  ...      ...      ...      ...
# 2019-08-23      medium   MSFT      8  2019   23   137.19   133.39   138.35
# 2019-08-23      medium   AAPL      8  2019   23   209.43   202.64   212.05
# 2019-08-23      medium  GOOGL      8  2019   23  1185.17  1153.58  1195.67
# 2019-08-23      medium   AMZN      8  2019   23  1793.03  1749.62  1804.90
# 2019-08-23      medium     FB      8  2019   23   180.84   177.75   183.13
#
#                 low    volume
# date
# ...

# %%
# total reset
tech.reset_index()
# Out:
#             date volume_type   name  month  year  day     open    close  \
# 0     2014-01-02      medium     FB      1  2014    2    54.86    54.71
# 1     2014-01-02         low   AAPL      1  2014    2    79.38    79.02
# 2     2014-01-02      medium  GOOGL      1  2014    2   557.73   556.56
# 3     2014-01-02      medium   MSFT      1  2014    2    37.35    37.16
# 4     2014-01-02      medium   AMZN      1  2014    2   398.80   397.97
# ...          ...         ...    ...    ...   ...  ...      ...      ...
# 7100  2019-08-23      medium   MSFT      8  2019   23   137.19   133.39
# 7101  2019-08-23      medium   AAPL      8  2019   23   209.43   202.64
# 7102  2019-08-23      medium  GOOGL      8  2019   23  1185.17  1153.58
# 7103  2019-08-23      medium   AMZN      8  2019   23  1793.03  1749.62
# 7104  2019-08-23      medium     FB      8  2019   23   180.84   177.75
#
#          high      low    volume
# 0       55.22    54.19  43257622
# 1       79.58    78.86   8398851
# ...

# %% [markdown]
# #### 184. Multiple sort_index()

# %%
try:
    tech.loc[(slice('2014-01-02','2014-04-02'),slice(None),slice('AAPL','FB')),'open':'low']
except Exception as e:
    print("Error: ",e)
# Out:
# Error:  'MultiIndex slicing requires the index to be lexsorted: slicing on levels [0, 2], lexsort depth 1'

# %%
tech.sort_index(inplace=True)

# %%
tech.loc[(slice('2014-01-02','2014-04-02'),slice(None),slice('AAPL','FB')),'open':'low']
# Out:
#                                open   close    high     low
# date       volume_type name
# 2014-01-02 low         AAPL   79.38   79.02   79.58   78.86
#            medium      AMZN  398.80  397.97  399.36  394.02
#                        FB     54.86   54.71   55.22   54.19
# 2014-01-03 low         AAPL   79.00   77.28   79.10   77.20
#            medium      AMZN  398.29  396.44  402.71  396.22
# ...                             ...     ...     ...     ...
# 2014-04-01 low         AAPL   76.84   77.38   77.41   76.68
#            medium      AMZN  338.35  342.99  344.43  338.00
# 2014-04-02 high        FB     63.24   62.72   63.91   62.21
#            low         AAPL   77.48   77.51   77.64   77.18
#            medium      AMZN  345.99  341.96  348.30  340.38
#
# [189 rows x 4 columns]

# %% [markdown]
# Always consider sorting the index
# Advantages:
# - improves retrieval performance, which becomes significant
#     - gor large dataframes, or
#     - frequent retrieval
# - enables slicing syntax
# - overall a good practice when working with tabular data representations, including pandas, Excel, SQL, etc

# %% [markdown]
# ##### sorting different levels in different orders

# %%
tech.sort_index(level=(0,2), ascending=[False,True])
# Out:
#                               month  year  day     open    close     high  \
# date       volume_type name
# 2019-08-23 medium      AAPL       8  2019   23   209.43   202.64   212.05
#                        AMZN       8  2019   23  1793.03  1749.62  1804.90
#                        FB         8  2019   23   180.84   177.75   183.13
#                        GOOGL      8  2019   23  1185.17  1153.58  1195.67
#                        MSFT       8  2019   23   137.19   133.39   138.35
# ...                             ...   ...  ...      ...      ...      ...
# 2014-01-02 low         AAPL       1  2014    2    79.38    79.02    79.58
#            medium      AMZN       1  2014    2   398.80   397.97   399.36
#                        FB         1  2014    2    54.86    54.71    55.22
#                        GOOGL      1  2014    2   557.73   556.56   558.88
#                        MSFT       1  2014    2    37.35    37.16    37.40
#
#                                   low    volume
# ...

# %% [markdown]
# #### 185. More MultiIndex Methods

# %% [markdown]
# ##### lexsorted()

# %%
tidx = tech.index

# %%
type(tidx)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
tidx.sortlevel(0,ascending=False, sort_remaining=True)
# Out:
# (MultiIndex([('2019-08-23', 'medium',  'MSFT'),
#              ('2019-08-23', 'medium', 'GOOGL'),
#              ('2019-08-23', 'medium',    'FB'),
#              ('2019-08-23', 'medium',  'AMZN'),
#              ('2019-08-23', 'medium',  'AAPL'),
#              ('2019-08-22', 'medium',  'MSFT'),
#              ('2019-08-22', 'medium',  'AMZN'),
#              ('2019-08-22', 'medium',  'AAPL'),
#              ('2019-08-22',    'low', 'GOOGL'),
#              ('2019-08-22',    'low',    'FB'),
#              ...
#              ('2014-01-03', 'medium',  'MSFT'),
#              ('2014-01-03', 'medium', 'GOOGL'),
#              ('2014-01-03', 'medium',    'FB'),
#              ('2014-01-03', 'medium',  'AMZN'),
#              ('2014-01-03',    'low',  'AAPL'),
#              ('2014-01-02', 'medium',  'MSFT'),
#              ('2014-01-02', 'medium', 'GOOGL'),
#              ('2014-01-02', 'medium',    'FB'),
#              ('2014-01-02', 'medium',  'AMZN'),
# ...

# %%
tidx.sortlevel((0,1,2),ascending=[True,True,False])
# Out:
# (MultiIndex([('2014-01-02',    'low',  'AAPL'),
#              ('2014-01-02', 'medium',  'MSFT'),
#              ('2014-01-02', 'medium', 'GOOGL'),
#              ('2014-01-02', 'medium',    'FB'),
#              ('2014-01-02', 'medium',  'AMZN'),
#              ('2014-01-03',    'low',  'AAPL'),
#              ('2014-01-03', 'medium',  'MSFT'),
#              ('2014-01-03', 'medium', 'GOOGL'),
#              ('2014-01-03', 'medium',    'FB'),
#              ('2014-01-03', 'medium',  'AMZN'),
#              ...
#              ('2019-08-22',    'low', 'GOOGL'),
#              ('2019-08-22',    'low',    'FB'),
#              ('2019-08-22', 'medium',  'MSFT'),
#              ('2019-08-22', 'medium',  'AMZN'),
#              ('2019-08-22', 'medium',  'AAPL'),
#              ('2019-08-23', 'medium',  'MSFT'),
#              ('2019-08-23', 'medium', 'GOOGL'),
#              ('2019-08-23', 'medium',    'FB'),
#              ('2019-08-23', 'medium',  'AMZN'),
# ...

# %% [markdown]
# ##### set_names()

# %%
tidx.set_names(['Trading Date','Volume Categoy','Ticker'],inplace=True)

# %%
tech.head()
# Out:
#                                     month  year  day    open   close    high  \
# Trading Date Volume Categoy Ticker
# 2014-01-02   low            AAPL        1  2014    2   79.38   79.02   79.58
#              medium         AMZN        1  2014    2  398.80  397.97  399.36
#                             FB          1  2014    2   54.86   54.71   55.22
#                             GOOGL       1  2014    2  557.73  556.56  558.88
#                             MSFT        1  2014    2   37.35   37.16   37.40
#
#                                        low    volume
# Trading Date Volume Categoy Ticker
# 2014-01-02   low            AAPL     78.86   8398851
#              medium         AMZN    394.02   2140246
#                             FB       54.19  43257622
#                             GOOGL   554.13   1822719
#                             MSFT     37.10  30643745

# %% [markdown]
# ##### to_flat_index()

# %%
# lo separa en tuplas
tidx.to_flat_index()
# Out:
# Index([    ('2014-01-02', 'low', 'AAPL'),  ('2014-01-02', 'medium', 'AMZN'),
#           ('2014-01-02', 'medium', 'FB'), ('2014-01-02', 'medium', 'GOOGL'),
#         ('2014-01-02', 'medium', 'MSFT'),     ('2014-01-03', 'low', 'AAPL'),
#         ('2014-01-03', 'medium', 'AMZN'),    ('2014-01-03', 'medium', 'FB'),
#        ('2014-01-03', 'medium', 'GOOGL'),  ('2014-01-03', 'medium', 'MSFT'),
#        ...
#              ('2019-08-22', 'low', 'FB'),    ('2019-08-22', 'low', 'GOOGL'),
#         ('2019-08-22', 'medium', 'AAPL'),  ('2019-08-22', 'medium', 'AMZN'),
#         ('2019-08-22', 'medium', 'MSFT'),  ('2019-08-23', 'medium', 'AAPL'),
#         ('2019-08-23', 'medium', 'AMZN'),    ('2019-08-23', 'medium', 'FB'),
#        ('2019-08-23', 'medium', 'GOOGL'),  ('2019-08-23', 'medium', 'MSFT')],
#       dtype='object', length=7105)

# %%
tech.close
# Out:
# Trading Date  Volume Categoy  Ticker
# 2014-01-02    low             AAPL        79.02
#               medium          AMZN       397.97
#                               FB          54.71
#                               GOOGL      556.56
#                               MSFT        37.16
#                                          ...
# 2019-08-23    medium          AAPL       202.64
#                               AMZN      1749.62
#                               FB         177.75
#                               GOOGL     1153.58
#                               MSFT       133.39
# Name: close, Length: 7105, dtype: float64

# %% [markdown]
# #### 186. Reshaping With stack()

# %% [markdown]
# ##### stack()

# %%
stacked = tech.stack()

# %%
# transform dataframe to series. 
stacked.head(10)
# Out:
# Trading Date  Volume Categoy  Ticker
# 2014-01-02    low             AAPL    month           1.00
#                                       year         2014.00
#                                       day             2.00
#                                       open           79.38
#                                       close          79.02
#                                       high           79.58
#                                       low            78.86
#                                       volume    8398851.00
#               medium          AMZN    month           1.00
#                                       year         2014.00
# dtype: float64

# %%
names = stacked.index.names

# %%
stacked.index.set_names([*names[:-1],'Previously a Column Axis'], inplace=True)

# %%
stacked.head()
# Out:
# Trading Date  Volume Categoy  Ticker  Previously a Column Axis
# 2014-01-02    low             AAPL    month                          1.00
#                                       year                        2014.00
#                                       day                            2.00
#                                       open                          79.38
#                                       close                         79.02
# dtype: float64

# %% [markdown]
# #### 187. The Flipside: unstack()

# %%
# does the opposite of stack
stacked.unstack()
# Out:
# Previously a Column Axis            month    year   day     open    close  \
# Trading Date Volume Categoy Ticker
# 2014-01-02   low            AAPL      1.0  2014.0   2.0    79.38    79.02
#              medium         AMZN      1.0  2014.0   2.0   398.80   397.97
#                             FB        1.0  2014.0   2.0    54.86    54.71
#                             GOOGL     1.0  2014.0   2.0   557.73   556.56
#                             MSFT      1.0  2014.0   2.0    37.35    37.16
# ...                                   ...     ...   ...      ...      ...
# 2019-08-23   medium         AAPL      8.0  2019.0  23.0   209.43   202.64
#                             AMZN      8.0  2019.0  23.0  1793.03  1749.62
#                             FB        8.0  2019.0  23.0   180.84   177.75
#                             GOOGL     8.0  2019.0  23.0  1185.17  1153.58
#                             MSFT      8.0  2019.0  23.0   137.19   133.39
#
# ...

# %%
stacked.unstack(level=2).head()
# Out:
# Ticker                                                   AAPL  AMZN  FB  \
# Trading Date Volume Categoy Previously a Column Axis
# 2014-01-02   low            month                        1.00   NaN NaN
#                             year                      2014.00   NaN NaN
#                             day                          2.00   NaN NaN
#                             open                        79.38   NaN NaN
#                             close                       79.02   NaN NaN
#
# Ticker                                                GOOGL  MSFT
# Trading Date Volume Categoy Previously a Column Axis
# 2014-01-02   low            month                       NaN   NaN
#                             year                        NaN   NaN
#                             day                         NaN   NaN
#                             open                        NaN   NaN
#                             close                       NaN   NaN

# %% [markdown]
# #### 188.  BONUS: Creating MultiLevel Columns Manually

# %% [markdown]
# LET´S BUILD ONE MANUALLY:
#
# CRITERIA:
# - 2-LEVEL MULTIINDEX COLUMN AXIS, CONTAINING:
#     - TRADING VOLUME (HIGH AND LOW) AND TICKERS (MSFT AND AMZN)
#     - 10 RANDOMN CLOSING PRICE OBSERVATIONS

# %%
tech.reset_index(inplace= True)

# %%
tech.head()
# Out:
#   Trading Date Volume Categoy Ticker  month  year  day    open   close  \
# 0   2014-01-02            low   AAPL      1  2014    2   79.38   79.02
# 1   2014-01-02         medium   AMZN      1  2014    2  398.80  397.97
# 2   2014-01-02         medium     FB      1  2014    2   54.86   54.71
# 3   2014-01-02         medium  GOOGL      1  2014    2  557.73  556.56
# 4   2014-01-02         medium   MSFT      1  2014    2   37.35   37.16
#
#      high     low    volume
# 0   79.58   78.86   8398851
# 1  399.36  394.02   2140246
# 2   55.22   54.19  43257622
# 3  558.88  554.13   1822719
# 4   37.40   37.10  30643745

# %% [markdown]
# ##### step 1: create multiindex

# %%
cols = pd.MultiIndex.from_product([['low','high'],['MSFT','AMZN']], names = ['Volume Category', 'Ticker'])

# %%
cols
# Out:
# MultiIndex([( 'low', 'MSFT'),
#             ( 'low', 'AMZN'),
#             ('high', 'MSFT'),
#             ('high', 'AMZN')],
#            names=['Volume Category', 'Ticker'])

# %% [markdown]
# ##### step 2: prep the undelying data

# %%
low = tech['Volume Categoy'] == 'low'
high = tech['Volume Categoy'] == 'high'
amzn = tech['Ticker'] == 'AMZN'
msft = tech['Ticker'] == 'MSFT'

# %%
data = [
    tech[low & msft].close.sample(10).values,
    tech[low & amzn].close.sample(10).values,
    tech[high & msft].close.sample(10).values,
    tech[high & amzn].close.sample(10).values
]

# %%
data = [ [*i] for i in zip(*data)]
data
# Out:
# [[60.53, 780.37, 36.48, 1719.36],
#  [120.33, 335.78, 42.71, 1100.95],
#  [85.4, 339.04, 47.52, 1642.81],
#  [73.87, 371.92, 37.84, 1520.91],
#  [85.71, 332.91, 47.66, 488.1],
#  [41.11, 780.22, 40.16, 502.13],
#  [74.26, 334.02, 50.99, 311.78],
#  [103.07, 384.61, 55.09, 776.32],
#  [75.21, 335.13, 41.68, 1339.6],
#  [76.0, 319.32, 51.64, 403.01]]

# %%
df = pd.DataFrame(data,columns=cols)
df
# Out:
# Volume Category     low           high
# Ticker             MSFT    AMZN   MSFT     AMZN
# 0                 60.53  780.37  36.48  1719.36
# 1                120.33  335.78  42.71  1100.95
# 2                 85.40  339.04  47.52  1642.81
# 3                 73.87  371.92  37.84  1520.91
# 4                 85.71  332.91  47.66   488.10
# 5                 41.11  780.22  40.16   502.13
# 6                 74.26  334.02  50.99   311.78
# 7                103.07  384.61  55.09   776.32
# 8                 75.21  335.13  41.68  1339.60
# 9                 76.00  319.32  51.64   403.01

# %%
df.columns.nlevels
# Out:
# 2

# %% [markdown]
# #### 189. An Easier Way: transpose()

# %% [markdown]
# - multiindex columns = set_index() + transpose()
#
# - set_index(): create multiindex
# - transpose(): swap columns with index

# %%
tech.head()
# Out:
#   Trading Date Volume Categoy Ticker  month  year  day    open   close  \
# 0   2014-01-02            low   AAPL      1  2014    2   79.38   79.02
# 1   2014-01-02         medium   AMZN      1  2014    2  398.80  397.97
# 2   2014-01-02         medium     FB      1  2014    2   54.86   54.71
# 3   2014-01-02         medium  GOOGL      1  2014    2  557.73  556.56
# 4   2014-01-02         medium   MSFT      1  2014    2   37.35   37.16
#
#      high     low    volume
# 0   79.58   78.86   8398851
# 1  399.36  394.02   2140246
# 2   55.22   54.19  43257622
# 3  558.88  554.13   1822719
# 4   37.40   37.10  30643745

# %%
tech.set_index(['Trading Date','Volume Categoy']).transpose()
# Out:
# Trading Date   2014-01-02                                       2014-01-03  \
# Volume Categoy        low   medium    medium   medium    medium        low
# Ticker               AAPL     AMZN        FB    GOOGL      MSFT       AAPL
# month                   1        1         1        1         1          1
# year                 2014     2014      2014     2014      2014       2014
# day                     2        2         2        2         2          3
# open                79.38    398.8     54.86   557.73     37.35       79.0
# close               79.02   397.97     54.71   556.56     37.16      77.28
# high                79.58   399.36     55.22   558.88      37.4       79.1
# low                 78.86   394.02     54.19   554.13      37.1       77.2
# volume            8398851  2140246  43257622  1822719  30643745   14043410
#
# Trading Date                                          ... 2019-08-22           \
# ...

# %% [markdown]
# #### 191. Skill Challenge

# %% [markdown]
# ##### 1. Change the index of the tech dataframe to a 3-level Multiindex containing year, month, and day on levels 0,1,2 respectively. Set resulting dataframe to dataframe to the variable tech_df3

# %%
tech_df3 = tech.set_index(['year','month','day'])

# %%
tech_df3
# Out:
#                Trading Date Volume Categoy Ticker     open    close     high  \
# year month day
# 2014 1     2     2014-01-02            low   AAPL    79.38    79.02    79.58
#            2     2014-01-02         medium   AMZN   398.80   397.97   399.36
#            2     2014-01-02         medium     FB    54.86    54.71    55.22
#            2     2014-01-02         medium  GOOGL   557.73   556.56   558.88
#            2     2014-01-02         medium   MSFT    37.35    37.16    37.40
# ...                     ...            ...    ...      ...      ...      ...
# 2019 8     23    2019-08-23         medium   AAPL   209.43   202.64   212.05
#            23    2019-08-23         medium   AMZN  1793.03  1749.62  1804.90
#            23    2019-08-23         medium     FB   180.84   177.75   183.13
#            23    2019-08-23         medium  GOOGL  1185.17  1153.58  1195.67
#            23    2019-08-23         medium   MSFT   137.19   133.39   138.35
#
# ...

# %% [markdown]
# ##### 2. From the tech_df3 dataaset, select all the trading days from the year 2019
# ##### In addition, add the existing column axis as the 4th level of the multiindex.
# ##### Assign the resulting series to the variable tech_series

# %%
tech_series = tech_df3.loc[slice(2019,2019),slice(None),slice(None)].stack()
tech_series
# Out:
# year  month  day
# 2019  1      2    Trading Date      2019-01-02
#                   Volume Categoy        medium
#                   Ticker                  AAPL
#                   open                  154.89
#                   close                 157.92
#                                        ...
#       8      23   open                  137.19
#                   close                 133.39
#                   high                  138.35
#                   low                    132.8
#                   volume              38515386
# Length: 6520, dtype: object

# %%
tech_series.index.set_names(['Year','Month','Day','Rest'],inplace=True)
tech_series
# Out:
# Year  Month  Day  Rest
# 2019  1      2    Trading Date      2019-01-02
#                   Volume Categoy        medium
#                   Ticker                  AAPL
#                   open                  154.89
#                   close                 157.92
#                                        ...
#       8      23   open                  137.19
#                   close                 133.39
#                   high                  138.35
#                   low                    132.8
#                   volume              38515386
# Length: 6520, dtype: object

# %% [markdown]
# ##### 3. From the tech_series dataframe, find the average close price and it´s standar deviation

# %%
tech_series_std = tech_series.loc[(slice(None),slice(None),slice(None),'close')].std()
tech_series_mean = tech_series.loc[(slice(None),slice(None),slice(None),'close')].mean()

print(f"Standar Deviation : {tech_series_std}")
print(f"Mean : {tech_series_mean}")
# Out:
# Standar Deviation : 677.2268499713305
# Mean : 686.3976196319019
